# %%
import pandas as pd 
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install tabula-py
# !pip install jpype1

# %%
from tabula import read_pdf
df = read_pdf('jan_2023_data_for_website.pdf', pages="all")

# %%
# df

# %%
data = pd.concat(df, ignore_index=True)
data
# Out:
#              STATE/UT        DISTRICT TEHSIL/BLOCK       VILLAGE NAME  \
# 0                 NaN             NaN         NAME                NaN
# 1                 NaN             NaN          NaN                NaN
# 2      Andhra Pradesh       Anantapur   Amarapuram       Palasamudram
# 3      Andhra Pradesh       Anantapur      Atmakur            Atmakur
# 4      Andhra Pradesh       Anantapur      Atmakur         Waddipalli
# ...               ...             ...          ...                ...
# 18774     West Bengal  West Medinipur       Rohini  Naikansole Colony
# 18775             NaN             NaN          NaN                NaN
# 18776     West Bengal  West Medinipur      Salboni              Gobru
# 18777     West Bengal  West Medinipur      Salboni         Godapiasal
# 18778     West Bengal  West Medinipur        Silda        Muohi Bundh
#
#           SITE NAME  LATITUDE LONGITUDE WELL SITE TYPE   WATER  \
# ...

# %%
data.shape
# Out:
# (18779, 21)

# %%
# data.isnull().sum

# %%
d = pd.DataFrame(data)

# %%
d
# Out:
#              STATE/UT        DISTRICT TEHSIL/BLOCK       VILLAGE NAME  \
# 0                 NaN             NaN         NAME                NaN
# 1                 NaN             NaN          NaN                NaN
# 2      Andhra Pradesh       Anantapur   Amarapuram       Palasamudram
# 3      Andhra Pradesh       Anantapur      Atmakur            Atmakur
# 4      Andhra Pradesh       Anantapur      Atmakur         Waddipalli
# ...               ...             ...          ...                ...
# 18774     West Bengal  West Medinipur       Rohini  Naikansole Colony
# 18775             NaN             NaN          NaN                NaN
# 18776     West Bengal  West Medinipur      Salboni              Gobru
# 18777     West Bengal  West Medinipur      Salboni         Godapiasal
# 18778     West Bengal  West Medinipur        Silda        Muohi Bundh
#
#           SITE NAME  LATITUDE LONGITUDE WELL SITE TYPE   WATER  \
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18779 entries, 0 to 18778
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   STATE/UT                   16757 non-null  object
#  1   DISTRICT                   16531 non-null  object
#  2   TEHSIL/BLOCK               17198 non-null  object
#  3   VILLAGE NAME               16391 non-null  object
#  4   SITE NAME                  16524 non-null  object
#  5   LATITUDE                   16228 non-null  object
#  6   LONGITUDE                  16580 non-null  object
#  7   WELL SITE TYPE             16489 non-null  object
#  8   WATER                      17816 non-null  object
#  9   SITE NAME LATITUDE         379 non-null    object
#  10  Unnamed: 0                 0 non-null      float64
#  11  STATE/UT DISTRICT          64 non-null     object
#  12  TEHSIL/BLOCK VILLAGE NAME  151 non-null    object
# ...

# %%
# print(d.drop('Delhi'))
d
# Out:
#              STATE/UT        DISTRICT TEHSIL/BLOCK       VILLAGE NAME  \
# 0                 NaN             NaN         NAME                NaN
# 1                 NaN             NaN          NaN                NaN
# 2      Andhra Pradesh       Anantapur   Amarapuram       Palasamudram
# 3      Andhra Pradesh       Anantapur      Atmakur            Atmakur
# 4      Andhra Pradesh       Anantapur      Atmakur         Waddipalli
# ...               ...             ...          ...                ...
# 18774     West Bengal  West Medinipur       Rohini  Naikansole Colony
# 18775             NaN             NaN          NaN                NaN
# 18776     West Bengal  West Medinipur      Salboni              Gobru
# 18777     West Bengal  West Medinipur      Salboni         Godapiasal
# 18778     West Bengal  West Medinipur        Silda        Muohi Bundh
#
#           SITE NAME  LATITUDE LONGITUDE WELL SITE TYPE   WATER  \
# ...

# %%
d = d.iloc[:, :9]  # Keep only the first 9 columns
d
# Out:
#              STATE/UT        DISTRICT TEHSIL/BLOCK       VILLAGE NAME  \
# 0                 NaN             NaN         NAME                NaN
# 1                 NaN             NaN          NaN                NaN
# 2      Andhra Pradesh       Anantapur   Amarapuram       Palasamudram
# 3      Andhra Pradesh       Anantapur      Atmakur            Atmakur
# 4      Andhra Pradesh       Anantapur      Atmakur         Waddipalli
# ...               ...             ...          ...                ...
# 18774     West Bengal  West Medinipur       Rohini  Naikansole Colony
# 18775             NaN             NaN          NaN                NaN
# 18776     West Bengal  West Medinipur      Salboni              Gobru
# 18777     West Bengal  West Medinipur      Salboni         Godapiasal
# 18778     West Bengal  West Medinipur        Silda        Muohi Bundh
#
#           SITE NAME  LATITUDE LONGITUDE WELL SITE TYPE   WATER
# 0               NaN       NaN       NaN            NaN   LEVEL
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18779 entries, 0 to 18778
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   STATE/UT        16757 non-null  object
#  1   DISTRICT        16531 non-null  object
#  2   TEHSIL/BLOCK    17198 non-null  object
#  3   VILLAGE NAME    16391 non-null  object
#  4   SITE NAME       16524 non-null  object
#  5   LATITUDE        16228 non-null  object
#  6   LONGITUDE       16580 non-null  object
#  7   WELL SITE TYPE  16489 non-null  object
#  8   WATER           17816 non-null  object
# dtypes: object(9)
# memory usage: 1.3+ MB

# %%
# d = d.rename(columns={
#     "STATE/UT": "STATE",
#     "TEHSIL/BLOCK": "TEHSIL",
#     "VILLAGE NAME": "Village",
#     "SITE NAME": "Site",
#     "WELL SITE TYPE": "WellType"
# })
d.columns = ["STATE", "DISTRICT","TEHSIL", "Village", "Site", "LATITUDE","LONGITUDE","WellType","WATER"]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18779 entries, 0 to 18778
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STATE      16757 non-null  object
#  1   DISTRICT   16531 non-null  object
#  2   TEHSIL     17198 non-null  object
#  3   Village    16391 non-null  object
#  4   Site       16524 non-null  object
#  5   LATITUDE   16228 non-null  object
#  6   LONGITUDE  16580 non-null  object
#  7   WellType   16489 non-null  object
#  8   WATER      17816 non-null  object
# dtypes: object(9)
# memory usage: 1.3+ MB

# %%
print(d.columns)
# Out:
# Index(['STATE', 'DISTRICT', 'TEHSIL', 'Village', 'Site', 'LATITUDE',
#        'LONGITUDE', 'WellType', 'WATER'],
#       dtype='object')

# %%
d
# Out:
#                 STATE        DISTRICT      TEHSIL            Village  \
# 0                 NaN             NaN        NAME                NaN
# 1                 NaN             NaN         NaN                NaN
# 2      Andhra Pradesh       Anantapur  Amarapuram       Palasamudram
# 3      Andhra Pradesh       Anantapur     Atmakur            Atmakur
# 4      Andhra Pradesh       Anantapur     Atmakur         Waddipalli
# ...               ...             ...         ...                ...
# 18774     West Bengal  West Medinipur      Rohini  Naikansole Colony
# 18775             NaN             NaN         NaN                NaN
# 18776     West Bengal  West Medinipur     Salboni              Gobru
# 18777     West Bengal  West Medinipur     Salboni         Godapiasal
# 18778     West Bengal  West Medinipur       Silda        Muohi Bundh
#
#                Site  LATITUDE LONGITUDE   WellType   WATER
# 0               NaN       NaN       NaN        NaN   LEVEL
# ...

# %%
d = d.dropna(subset=["LATITUDE"])

# %%
d = d.dropna(subset=["LONGITUDE"])

# %%
d = d.dropna(subset=["Site"])

# %%
d = d.dropna(subset=["STATE"])

# %%
d = d.dropna(subset=["DISTRICT"])

# %%
d = d.dropna(subset=["TEHSIL"])

# %%
d = d.dropna(subset=["Village"])

# %%
d = d.dropna(subset=["WATER"])

# %%
d
# Out:
#                 STATE        DISTRICT             TEHSIL            Village  \
# 2      Andhra Pradesh       Anantapur         Amarapuram       Palasamudram
# 3      Andhra Pradesh       Anantapur            Atmakur            Atmakur
# 4      Andhra Pradesh       Anantapur            Atmakur         Waddipalli
# 5      Andhra Pradesh       Anantapur  Bukkarayasamudram          Korrapadu
# 6      Andhra Pradesh       Anantapur  Bukkarayasamudram       Regadikoturu
# ...               ...             ...                ...                ...
# 18773     West Bengal  West Medinipur        Narayangarh          Nekursini
# 18774     West Bengal  West Medinipur             Rohini  Naikansole Colony
# 18776     West Bengal  West Medinipur            Salboni              Gobru
# 18777     West Bengal  West Medinipur            Salboni         Godapiasal
# 18778     West Bengal  West Medinipur              Silda        Muohi Bundh
#
# ...

# %%
d = d.drop(d.index[::30])  # Removes every 2th row
d
# Out:
#                 STATE        DISTRICT             TEHSIL            Village  \
# 3      Andhra Pradesh       Anantapur            Atmakur            Atmakur
# 4      Andhra Pradesh       Anantapur            Atmakur         Waddipalli
# 5      Andhra Pradesh       Anantapur  Bukkarayasamudram          Korrapadu
# 6      Andhra Pradesh       Anantapur  Bukkarayasamudram       Regadikoturu
# 7      Andhra Pradesh       Anantapur   Chennakothapalle  Chenna Kothapalli
# ...               ...             ...                ...                ...
# 18772     West Bengal  West Medinipur        Narayangarh          Makrampur
# 18773     West Bengal  West Medinipur        Narayangarh          Nekursini
# 18776     West Bengal  West Medinipur            Salboni              Gobru
# 18777     West Bengal  West Medinipur            Salboni         Godapiasal
# 18778     West Bengal  West Medinipur              Silda        Muohi Bundh
#
# ...

# %%
d = d.drop(d.index[::2])
d
# Out:
#                 STATE        DISTRICT             TEHSIL           Village  \
# 4      Andhra Pradesh       Anantapur            Atmakur        Waddipalli
# 6      Andhra Pradesh       Anantapur  Bukkarayasamudram      Regadikoturu
# 8      Andhra Pradesh       Anantapur        Dharmavaram       Dharmavaram
# 10     Andhra Pradesh       Anantapur        Dharmavaram  Dharmavaram-Ewll
# 12     Andhra Pradesh       Anantapur              Gooty             Gooty
# ...               ...             ...                ...               ...
# 18768     West Bengal  West Medinipur          Medinipur         Jamir Ara
# 18770     West Bengal  West Medinipur          Medinipur         Medinipur
# 18772     West Bengal  West Medinipur        Narayangarh         Makrampur
# 18776     West Bengal  West Medinipur            Salboni             Gobru
# 18778     West Bengal  West Medinipur              Silda       Muohi Bundh
#
#                    Site   LATITUDE LONGITUDE   WellType WATER
# ...

# %%
d = d[]
# Out:
#   Cell In[33], line 1
#     rand =
#            ^
# SyntaxError: invalid syntax

# %%
# d = d[d["WellType"] != "Dug Well"]
# d
# d = d.drop_duplicates(subset=['Dug Well'])

# %%
# d_sampled = d.sample(n=250, random_state=42)  # Selects 250 random rows
# # print(d_sampled)
# d_sampled.tail(60)

# %%
# # Drop rows where 'STATE' is NaN
# d_cleaned = d.dropna(subset=["STATE"])  

# # Get 10 rows per state (or fewer if not enough exist)
# d_sampled = d_cleaned.groupby("STATE", group_keys=False).apply(
#     lambda x: x.sample(n=min(10, len(x)), random_state=42)
# )

# print(d_sampled["STATE"].value_counts())  # Check how many rows per state
# # print(d_sampled)  # View the final sampled dataset
# d_sampled.isnull().sum
# d_sampled.info()

# %%
# d.to_csv("waterData03.csv", index= False)
# df.to_csv('movies_cleaned01.csv', index= False)
# d.to_json("waterData03.js", orient="records")
